# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-Tagde/Assignment/blob/main/rightmove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.rightmove.co.uk/house-prices/dagenham.html'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-GB">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>House Prices in Dagenham</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="The average price for a property in Dagenham is £350,732 over the last year. Explore Rightmove house prices to find out how much properties sold for in Dagenham." name="description"/>
# <link href="https://media.rightmove.co.uk/assets/shared-assets/favicons/light/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <!-- APPLE ICONS -->
# <link href="https://media.rightmove.co.uk/assets/shared-assets/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://media.rightmove.co.uk/assets/shared-assets/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# ...

# %%
results = soup.find_all('a', {'class': 'gKlBdi6E4F4h7uvAX38x'})

# %%
len(results)
# Out:
# 25

# %%
results[0]
# Out:
# <a class="gKlBdi6E4F4h7uvAX38x" data-testid="propertyCard" href="https://www.rightmove.co.uk/house-prices/details/england-154598774-22873066?s=e10177e7d2bc48d27fc64d518d4e60bf46ffa60c6fd3628aabdb7c856e252909" tabindex="0"><div class="U_bIwRI2FjLNv4ZUFwda"><h3 class="SuZdruCTWFpfzw_MT0Ht">7, Cambeys Road, Dagenham, Greater London RM10 8YA</h3></div><div class="qnXUaraj2UEm7uKxxyg0"><img alt="Property image" class="D_QQ6MR9OMcRe40bCwyQ" loading="lazy" src="https://media.rightmove.co.uk/dir/8k/7492/154598774/7492_33483512_IMG_00_0000_max_296x197.jpeg"/><div class="esykfkFh_BT8CZei0fsc"><svg aria-hidden="true" class="oUFVO5q8_m3CXrjAV2iY" fill="none" height="24" viewbox="0 0 24 24" width="24"><path d="M5 19h5v2H5c-1.1046 0-2-.8954-2-2V3h18v16c0 1.1046-.8954 2-2 2h-5v-2h5v-8h-3v4c0 .5523-.4477 1-1 1s-1-.4477-1-1v-5c0-.5523.4477-1 1-1h4V5h-8v5c0 .5523-.4477 1-1 1s-1-.4477-1-1V5H5v9h5c.5523 0 1 .4477 1 1s-.4477 1-1 1H5z" fill="currentColor"></path></svg><div class="EIPkaGSVVjCzQck12Fx3"></d
# ...

# %%
#Address
results[0].find('h3').get_text()
# Out:
# '7, Cambeys Road, Dagenham, Greater London RM10 8YA'

# %%
#Type
results[0].find('div', {'class':'l2ksC0_DsIQ5VWkN6aQk'}).get_text()
# Out:
# 'Semi-Detached'

# %%
#Tenure
results[0].find('div', class_='l2ksC0_DsIQ5VWkN6aQk', attrs={'aria-label': lambda x: x and 'Tenure' in x}).get_text()
# Out:
# 'Freehold'

# %%
#Bedroom
results[0].find('div', class_='l2ksC0_DsIQ5VWkN6aQk', attrs={'aria-label': lambda x: x and 'Bedrooms' in x}).get_text()
# Out:
# '3'

# %%
#Price
results[0].find('td', {'class':'eAeEgAzoQt7uJJ0H4Mom undefined'}).get_text()
# Out:
# '£450,000'

# %%
#Date
results[0].find('td', {'class':'eAeEgAzoQt7uJJ0H4Mom atz5tYnaqoJ2uRM7nl_f'}).get_text()
# Out:
# '24 Feb 2025'

# %%
Address = []
Type = []
Tenure = []
Bedroom = []
Price = []
Date = []

for result in results:
    #Address
    try:
        Address.append(result.find('h3').get_text())
    except:
        Address.append('n/a')
    #Type
    try:
        Type.append(result.find('div', {'class':'l2ksC0_DsIQ5VWkN6aQk'}).get_text())
    except:
        Type.append('n/a')
    #Tenure
    try:
        Tenure.append(result.find('div', class_='l2ksC0_DsIQ5VWkN6aQk', attrs={'aria-label': lambda x: x and 'Tenure' in x}).get_text())
    except:
        Tenure.append('n/a')
    #Bedroom
    try:
        Bedroom.append(result.find('div', class_='l2ksC0_DsIQ5VWkN6aQk', attrs={'aria-label': lambda x: x and 'Bedrooms' in x}).get_text())
    except:
        Bedroom.append('n/a')
    #Price
    try:
        Price.append(result.find('td', {'class':'eAeEgAzoQt7uJJ0H4Mom undefined'}).get_text())
    except:
        Price.append('n/a')
    #Date
    try:
        Date.append(result.find('td', {'class':'eAeEgAzoQt7uJJ0H4Mom atz5tYnaqoJ2uRM7nl_f'}).get_text())
    except:
        Date.append

# %%
Address
# Out:
# ['7, Cambeys Road, Dagenham, Greater London RM10 8YA',
#  '168, Valence Circus, Dagenham, Greater London RM8 3LT',
#  '5, Armstrong Close, Dagenham, Greater London RM8 1TF',
#  '10, Ellerton Road, Dagenham, Greater London RM9 4HX',
#  '6, Coopers Close, Dagenham, Greater London RM10 8TN',
#  '82a, Wood Lane, Dagenham, Greater London RM8 2NT',
#  '75, Oxlow Lane, Dagenham, Greater London RM9 5XD',
#  '34, Roberts Place, Dagenham, Greater London RM10 8SN',
#  '65, Gibson Road, Dagenham, Greater London RM8 1YE',
#  '35, Sheppey Road, Dagenham, Greater London RM9 4LH',
#  '10, Cherry Gardens, Dagenham, Greater London RM9 5BL',
#  '57, Barton Avenue, Romford, Greater London RM7 0NB',
#  '12, Western Avenue, Dagenham, Greater London RM10 8UB',
#  '5, Harris Road, Dagenham, Greater London RM9 5DT',
#  '394, Porters Avenue, Dagenham, Greater London RM8 2EF',
#  '270, Rugby Road, Dagenham, Greater London RM9 4AT',
#  '732, Longbridge Road, Dagenham, Greater London RM8 2AH',
# ...

# %%
Price
# Out:
# ['£450,000',
#  '£360,000',
#  '£336,000',
#  '£200,000',
#  '£345,000',
#  '£180,000',
#  '£340,000',
#  '£225,000',
#  '£390,000',
#  '£370,000',
#  '£220,000',
#  '£450,000',
#  '£395,000',
#  '£390,000',
#  '£379,000',
#  '£350,000',
#  '£362,500',
#  '£500,000',
#  '£375,000',
#  '£375,000',
#  '£450,000',
#  '£240,000',
#  '£205,000',
#  '£450,000',
#  '£410,000']

# %%
house_data = pd.DataFrame({'Address':Address, 'Type':Type, 'Tenure':Tenure, 'Bedroom':Bedroom, 'Price':Price, 'Date':Date})

# %%
house_data
# Out:
#                                               Address           Type  \
# 0   7, Cambeys Road, Dagenham, Greater London RM10...  Semi-Detached
# 1   168, Valence Circus, Dagenham, Greater London ...  Semi-Detached
# 2   5, Armstrong Close, Dagenham, Greater London R...       Terraced
# 3   10, Ellerton Road, Dagenham, Greater London RM...           Flat
# 4   6, Coopers Close, Dagenham, Greater London RM1...       Terraced
# 5    82a, Wood Lane, Dagenham, Greater London RM8 2NT           Flat
# 6    75, Oxlow Lane, Dagenham, Greater London RM9 5XD       Terraced
# 7   34, Roberts Place, Dagenham, Greater London RM...           Flat
# 8   65, Gibson Road, Dagenham, Greater London RM8 1YE       Terraced
# 9   35, Sheppey Road, Dagenham, Greater London RM9...       Terraced
# 10  10, Cherry Gardens, Dagenham, Greater London R...           Flat
# 11  57, Barton Avenue, Romford, Greater London RM7...  Semi-Detached
# 12  12, Western Avenue, Dagenham, Greater London R...       Terraced
# ...

# %%
df = pd.DataFrame(house_data)

# %%
df.to_excel('house_data.xlsx', index=False, engine='openpyxl')

# %%
from google.colab import files
files.download('house_data.xlsx')
